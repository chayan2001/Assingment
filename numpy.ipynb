# %%
"""
1. Explain the purpose and advantages of NumPy in scientific computing and data analysis. How does it
enhance Python's capabilities for numerical operations?


2. Compare and contrast np.mean() and np.average() functions in NumPy. When would you use one over the
other?


3. Describe the methods for reversing a NumPy array along different axes. Provide examples for 1D and 2D
arrays.


4. How can you determine the data type of elements in a NumPy array? Discuss the importance of data types
in memory management and performance.


5. Define ndarrays in NumPy and explain their key features. How do they differ from standard Python lists?


6. Analyze the performance benefits of NumPy arrays over Python lists for large-scale numerical operations.


7. Compare vstack() and hstack() functions in NumPy. Provide examples demonstrating their usage and
output.


8. Explain the differences between fliplr() and flipud() methods in NumPy, including their effects on various
array dimensions.


9. Discuss the functionality of the array_split() method in NumPy. How does it handle uneven splits?


10. Explain the concepts of vectorization and broadcasting in NumPy. How do they contribute to efficient array
operations?
"""
# Out:
# "\n1. Explain the purpose and advantages of NumPy in scientific computing and data analysis. How does it\nenhance Python's capabilities for numerical operations?\n\n\n2. Compare and contrast np.mean() and np.average() functions in NumPy. When would you use one over the\nother?\n\n\n3. Describe the methods for reversing a NumPy array along different axes. Provide examples for 1D and 2D\narrays.\n\n\n4. How can you determine the data type of elements in a NumPy array? Discuss the importance of data types\nin memory management and performance.\n\n\n5. Define ndarrays in NumPy and explain their key features. How do they differ from standard Python lists?\n\n\n6. Analyze the performance benefits of NumPy arrays over Python lists for large-scale numerical operations.\n\n\n7. Compare vstack() and hstack() functions in NumPy. Provide examples demonstrating their usage and\noutput.\n\n\n8. Explain the differences between fliplr() and flipud() methods in NumPy, including their effects on vario
# ...

# %%
"""

# Answers:

# 1. Purpose and Advantages of NumPy:

# NumPy is a fundamental library for scientific computing in Python. It provides support for
# multi-dimensional arrays (ndarrays), along with a collection of high-level mathematical functions
# to operate on these arrays.

# Advantages:
# - **Efficient Numerical Operations:** NumPy arrays are implemented in C, making them significantly
#   faster for numerical computations than standard Python lists.
# - **Broadcasting:** NumPy allows for element-wise operations between arrays of different shapes
#   and sizes, making code more concise and efficient.
# - **Vectorization:** NumPy enables vectorized operations, eliminating the need for explicit loops,
#   which leads to cleaner and faster code.
# - **Linear Algebra, Fourier Transforms, Random Number Generation:** NumPy offers powerful functions
#   for linear algebra, Fourier transforms, and random number generation.


# 2. np.mean() vs. np.average():

# `np.mean()` calculates the arithmetic mean of an array.
# `np.average()` allows you to specify weights for each element when computing the average.

# Use `np.mean()` when you want the simple arithmetic average.
# Use `np.average()` when you need a weighted average.

# Example:
# import numpy as np
# arr = np.array([1, 2, 3, 4, 5])
# mean_val = np.mean(arr)
# weighted_avg = np.average(arr, weights=[0.1, 0.2, 0.3, 0.2, 0.2])


# 3. Reversing a NumPy Array:

# You can reverse a NumPy array along different axes using array slicing with a step of -1.

# 1D Example:
# import numpy as np
# arr1d = np.array([1, 2, 3, 4, 5])
# reversed_arr1d = arr1d[::-1]

# 2D Example:
# arr2d = np.array([[1, 2, 3], [4, 5, 6]])
# reversed_arr2d_rows = arr2d[::-1, :]  # Reverse rows
# reversed_arr2d_cols = arr2d[:, ::-1]  # Reverse columns


# 4. Determining Data Type and Its Importance:

# You can determine the data type of elements in a NumPy array using the `dtype` attribute.

# Example:
# import numpy as np
# arr = np.array([1, 2, 3])
# print(arr.dtype)

# Data types are crucial for memory management and performance because they dictate how much
# memory is allocated for each element and how operations are performed. Choosing the appropriate
# data type (e.g., int8, int32, float64) can significantly affect memory usage and processing speed.


# 5. ndarrays in NumPy:

# ndarrays (N-dimensional arrays) are the fundamental data structure in NumPy. They are homogeneous,
# meaning they store elements of the same data type.

# Key Features:
# - Multi-dimensional: They can represent data in various dimensions (1D, 2D, 3D, etc.).
# - Fixed Size: The size of an ndarray is fixed at creation.
# - Efficient: They are implemented in C, making them efficient for numerical computations.
# - Vectorized Operations: They support element-wise operations and vectorized computations.

# Differences from Python lists:
# - **Data Type Homogeneity:** ndarrays have a single data type for all elements, whereas lists can
#   store elements of different data types.
# - **Memory Efficiency:** NumPy arrays are more memory-efficient than lists, particularly for large
#   datasets.
# - **Performance:** NumPy arrays are much faster for numerical operations.


# 6. Performance Benefits of NumPy Arrays:

# NumPy arrays provide significant performance benefits over Python lists, especially for large datasets
# and numerical operations. The primary reason is that NumPy arrays:
# - Are stored in contiguous memory blocks.
# - Are implemented in C, which allows for faster execution of operations.
# - Support vectorized operations, eliminating the need for explicit loops.


# 7. vstack() and hstack():

# `vstack()` (vertical stack) stacks arrays vertically (row-wise).
# `hstack()` (horizontal stack) stacks arrays horizontally (column-wise).

# Example:
# import numpy as np
# arr1 = np.array([1, 2, 3])
# arr2 = np.array([4, 5, 6])
# vstacked_arr = np.vstack((arr1, arr2))
# hstacked_arr = np.hstack((arr1, arr2))


# 8. fliplr() and flipud():

# `fliplr()` (flip left-right) flips an array horizontally (along the second axis).
# `flipud()` (flip up-down) flips an array vertically (along the first axis).


# Example:
# arr = np.array([[1, 2, 3], [4, 5, 6]])
# flipped_lr = np.fliplr(arr)
# flipped_ud = np.flipud(arr)


# 9. array_split():

# `array_split()` divides an array into multiple sub-arrays. It handles uneven splits by distributing
# the remaining elements among the sub-arrays.


# Example:
# arr = np.array([1, 2, 3, 4, 5, 6])
# sub_arrays = np.array_split(arr, 3)


# 10. Vectorization and Broadcasting:

# **Vectorization:** Performing operations on entire arrays at once, rather than using loops. This
# allows for more efficient computation.

# **Broadcasting:** A set of rules that allows NumPy to perform operations on arrays with different
# shapes, often by extending the smaller array to match the shape of the larger array.

# Both vectorization and broadcasting are crucial for achieving fast and efficient operations in NumPy.
# They enable you to write concise and elegant code while leveraging the performance of NumPy's
# underlying implementation.
"""
# Out:
# "\n\n# Answers:\n\n# 1. Purpose and Advantages of NumPy:\n\n# NumPy is a fundamental library for scientific computing in Python. It provides support for\n# multi-dimensional arrays (ndarrays), along with a collection of high-level mathematical functions\n# to operate on these arrays. \n\n# Advantages:\n# - **Efficient Numerical Operations:** NumPy arrays are implemented in C, making them significantly\n#   faster for numerical computations than standard Python lists.\n# - **Broadcasting:** NumPy allows for element-wise operations between arrays of different shapes\n#   and sizes, making code more concise and efficient.\n# - **Vectorization:** NumPy enables vectorized operations, eliminating the need for explicit loops,\n#   which leads to cleaner and faster code.\n# - **Linear Algebra, Fourier Transforms, Random Number Generation:** NumPy offers powerful functions\n#   for linear algebra, Fourier transforms, and random number generation. \n\n\n# 2. np.mean() vs. np.average():\n\n# `n
# ...

# %%
"""
**q1. Create a 3x3 NumPy array with random integers between 1 and 100. Then, interchange its rows and columns.**

```python
import numpy as np

# Create a 3x3 array with random integers between 1 and 100
arr = np.random.randint(1, 101, size=(3, 3))
print("Original array:\n", arr)

# Interchange rows and columns (transpose)
transposed_arr = arr.T
print("Transposed array (rows interchanged with columns):\n", transposed_arr)
```

---

**q2. Generate a 1D NumPy array with 10 elements. Reshape it into a 2x5 array, then into a 5x2 array.**

```python
# Create a 1D array with 10 elements
arr = np.arange(10)
print("1D array:\n", arr)

# Reshape into a 2x5 array
reshaped_2x5 = arr.reshape(2, 5)
print("Reshaped into 2x5 array:\n", reshaped_2x5)

# Reshape into a 5x2 array
reshaped_5x2 = arr.reshape(5, 2)
print("Reshaped into 5x2 array:\n", reshaped_5x2)
```

---

**q3. Create a 4x4 NumPy array with random float values. Add a border of zeros around it, resulting in a 6x6 array.**

```python
# Create a 4x4 array with random float values
arr = np.random.rand(4, 4)
print("Original 4x4 array:\n", arr)

# Add a border of zeros around it
arr_with_border = np.pad(arr, pad_width=1, mode='constant', constant_values=0)
print("6x6 array with zero border:\n", arr_with_border)
```

---

**q4. Using NumPy, create an array of integers from 10 to 60 with a step of 5.**

```python
arr = np.arange(10, 61, 5)
print("Array from 10 to 60 with step 5:\n", arr)
```

---

**q5. Create a NumPy array of strings ['python', 'numpy', 'pandas']. Apply different case transformations (uppercase, lowercase, title case, etc.) to each element.**

```python
# Create an array of strings
arr = np.array(['python', 'numpy', 'pandas'])

# Apply different case transformations
uppercase_arr = np.char.upper(arr)
lowercase_arr = np.char.lower(arr)
titlecase_arr = np.char.title(arr)

print("Uppercase:\n", uppercase_arr)
print("Lowercase:\n", lowercase_arr)
print("Title case:\n", titlecase_arr)
```

---

**q6. Generate a NumPy array of words. Insert a space between each character of every word in the array.**

```python
# Create an array of words
arr = np.array(['python', 'numpy', 'pandas'])

# Insert a space between each character of every word
spaced_arr = np.char.join(' ', arr)

print("Words with spaces between characters:\n", spaced_arr)
```

---

**q7. Create two 2D NumPy arrays and perform element-wise addition, subtraction, multiplication, and division.**

```python
# Create two 2D arrays
arr1 = np.array([[1, 2], [3, 4]])
arr2 = np.array([[5, 6], [7, 8]])

# Perform element-wise operations
add = np.add(arr1, arr2)
subtract = np.subtract(arr1, arr2)
multiply = np.multiply(arr1, arr2)
divide = np.divide(arr1, arr2)

print("Addition:\n", add)
print("Subtraction:\n", subtract)
print("Multiplication:\n", multiply)
print("Division:\n", divide)
```

---

**q8. Use NumPy to create a 5x5 identity matrix, then extract its diagonal elements.**

```python
# Create a 5x5 identity matrix
identity_matrix = np.eye(5)
print("5x5 Identity Matrix:\n", identity_matrix)

# Extract the diagonal elements
diagonal_elements = np.diag(identity_matrix)
print("Diagonal Elements:\n", diagonal_elements)
```

---

**q9. Generate a NumPy array of 100 random integers between 0 and 1000. Find and display all prime numbers in this array.**

```python
# Generate a
